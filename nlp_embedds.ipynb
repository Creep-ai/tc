# %%
nlp = spacy.load("ru_core_news_md")

# %%
# !python -m spacy download ru_core_news_md

# %%
org_1 = 'ГИМНАЗИЯ № 32, МУНИЦИПАЛЬНОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ,\
ГОРОД ИВАНОВО, РЯБКОВ СЕРГЕЙ СЕРГЕЕВИЧ, Образование основное общее'
org_2 = 'УК АРТВИС-МЕДИА, ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ,\
ГОРОД ЯРОСЛАВЛЬ, АГАМОВ ВЛАДИСЛАВ АЛЕКСАНДРОВИЧ, Деятельность в области права и бухгалтерского учета'
org_3 = 'САУНД ТРЭК, ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ,\
ГОРОД МОСКВА, АЙВАЗЯН РОМАН АРТУШЕВИЧ, Общая врачебная практика'
org_4 = 'ГИМНАЗИЯ № 3, МУНИЦИПАЛЬНОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ,\
ГОРОД ИВАНОВО, АХМАД ОКСАНА АЛЕКСАНДРОВНА, Образование среднее общее'
org_5 = 'ИВАНОВСКАЯ СРЕДНЯЯ ШКОЛА, МУНИЦИПАЛЬНОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ,\
ДЕРЕВНЯ ИВАНОВО, ЕФИМОВА СВЕТЛАНА АНАТОЛЬЕВНА, Образование среднее общее'

# %%
doc1 = nlp(org_1)
doc2 = nlp(org_2)
doc3 = nlp(org_3)
doc4 = nlp(org_4)
doc5 = nlp(org_5)

# %%
print(doc5.similarity(doc4))
print(doc5.similarity(doc3))
print(doc5.similarity(doc2))
print(doc5.similarity(doc1))
# Out:
# 0.9999999335191362
# 0.00460937168626394
# 0.06892654810854015
# 0.8117963337987402

# %%
x = doc1.vector

# %%
x.shape
# Out:
# (300,)
